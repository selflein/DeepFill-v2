# %%
# %cd ..
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
from iminpaint.data.dataloader.data_utils import generate_mask
import numpy as np

# %%
rows, cols = 5, 5
masks = [generate_mask((2, 5), (10, 50), (10, 50), (0, 1)).numpy() for _ in range(rows * cols)]

fig, ax = plt.subplots(rows, cols, figsize=(cols * 10, rows * 10))
for i in range(rows):
    for j in range(cols):
        ax[i][j].imshow(masks[i * rows + j])
print(np.unique(mask))
# Out:
# [0. 1.]
