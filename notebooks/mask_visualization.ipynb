# %%
# %cd ..
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/sven/Developer/git/iminpaint

# %%
import matplotlib.pyplot as plt
from iminpaint.data.dataloader.data_utils import generate_mask
import numpy as np

# %%
rows, cols = 5, 5
masks = [generate_mask((1, 5), (20, 50), (10, 40), (-0, np.pi)).numpy() for _ in range(rows * cols)]

fig, ax = plt.subplots(rows, cols, figsize=(cols * 10, rows * 10))
for i in range(rows):
    for j in range(cols):
        ax[i][j].imshow(masks[i * rows + j])
print(np.unique(masks[0]))
# Out:
# [0. 1.]

# %%
# %%timeit
generate_mask((8, 10), (20, 50), (20, 50), (0, np.pi / 2))
# Out:
# 149 µs ± 8.47 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
